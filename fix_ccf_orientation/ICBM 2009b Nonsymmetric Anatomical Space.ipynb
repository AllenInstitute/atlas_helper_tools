# %% [markdown]
# # ICBM 2009b Nonlinear Symmetric - Anatomical Space
#
# The **“ICBM 2009b Nonlinear Symmetric”** anatomical space is a MRI reference brain volume that is a non-linear average of the MNI152 database of 152 normal brain images. The iterative procedure results in an average that combines both high-spatial resolution and signal-to-noise and not subjected to any particularity of any single brain.
#
# To obtain the reference volume, refer to the McConnell Brain Imaging Center website for download and terms of use available from http://www.bic.mni.mcgill.ca/ServicesAtlases/ICBM152NLin2009
# (Copyright © 1993–2004 Louis Collins, McConnell Brain Imaging Centre, Montreal Neurological Institute, McGill University)
#
# The axes the average template volume is a +X=Right, +Y=Anterior and +Z=Superior frame with the origin at the [anterior commisure](http://purl.obolibrary.org/obo/UBERON_0000935) and 0.5x0.5x0.5 millimeter voxels.
#
# The average template volumetric files already conforms to standard medical imaging file formats that typically define axis as a transformation from a patient-based right-handed coordinate frame (+X=Right,+Y=Anterior,+Z=Superior) and many tools assumes the unit to be in millimeters.
#
#
# The parcellation of the **["Allen Human Reference Atlas - 3D, 2020"](https://community.brain-map.org/t/allen-human-reference-atlas-3d-2020-new)** are defined with respect to this reference volume.

# %% [markdown]
# **Screenshot of opening the file "mni_icbm152_t1_tal_nlin_sym_09b_hires.nii" in [ITK-SNAP](http://www.itksnap.org/pmwiki/pmwiki.php).**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Screenshot of opening the file "mni_icbm152_t1_tal_nlin_sym_09b_hires.nii" in [3D Slicer](https://slicer.readthedocs.io/en/latest/user_guide/getting_started.html).**
#
# ![slicer_icbm_2009b_oblique.png](slicer_icbm_2009b_oblique.png)
